# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("games.csv")

# %%
df.head()
# Out:
#          id  rated    created_at  last_move_at  turns victory_status winner  \
# 0  TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1  l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign  black
# 2  mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate  white
# 3  kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate  white
# 4  9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate  white
#
#   increment_code       white_id  white_rating      black_id  black_rating  \
# 0           15+2       bourgris          1500          a-00          1191
# 1           5+10           a-00          1322     skinnerua          1261
# 2           5+10         ischia          1496          a-00          1500
# 3           20+0  daniamurashov          1439  adivanov2009          1454
# 4           30+3      nik221107          1523  adivanov2009          1469
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime
# 1      l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign
# 2      mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate
# 3      kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate
# 4      9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate
# ...         ...    ...           ...           ...    ...            ...
# 20053  EfqH7VVH   True  1.499791e+12  1.499791e+12     24         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12     82           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12     35           mate
# 20056  b0v4tRyF   True  1.499696e+12  1.499697e+12    109         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12     78           mate
#
# ...

# %%
df.drop(['moves' , 'opening_name'] , axis = 1)
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime
# 1      l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign
# 2      mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate
# 3      kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate
# 4      9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate
# ...         ...    ...           ...           ...    ...            ...
# 20053  EfqH7VVH   True  1.499791e+12  1.499791e+12     24         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12     82           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12     35           mate
# 20056  b0v4tRyF   True  1.499696e+12  1.499697e+12    109         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12     78           mate
#
#       winner increment_code       white_id  white_rating            black_id  \
# ...

# %%
df1 = df.drop(['id' , 'created_at' , 'last_move_at' , 'victory_status' , 'opening_eco' , 'opening_name' , 'moves'] , axis = 1)

# %% [markdown]
# df.head()

# %%
df.head()
# Out:
#          id  rated    created_at  last_move_at  turns victory_status winner  \
# 0  TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1  l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign  black
# 2  mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate  white
# 3  kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate  white
# 4  9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate  white
#
#   increment_code       white_id  white_rating      black_id  black_rating  \
# 0           15+2       bourgris          1500          a-00          1191
# 1           5+10           a-00          1322     skinnerua          1261
# 2           5+10         ischia          1496          a-00          1500
# 3           20+0  daniamurashov          1439  adivanov2009          1454
# 4           30+3      nik221107          1523  adivanov2009          1469
#
# ...

# %%
df1.head()
# Out:
#    rated  turns winner increment_code       white_id  white_rating  \
# 0  False     13  white           15+2       bourgris          1500
# 1   True     16  black           5+10           a-00          1322
# 2   True     61  white           5+10         ischia          1496
# 3   True     61  white           20+0  daniamurashov          1439
# 4   True     95  white           30+3      nik221107          1523
#
#        black_id  black_rating  opening_ply
# 0          a-00          1191            5
# 1     skinnerua          1261            4
# 2          a-00          1500            3
# 3  adivanov2009          1454            3
# 4  adivanov2009          1469            5

# %%
df1 = df1.drop(['white_id' , 'black_id'] , axis = 1)

# %%
df1.head()
# Out:
#    rated  turns winner increment_code  white_rating  black_rating  opening_ply
# 0  False     13  white           15+2          1500          1191            5
# 1   True     16  black           5+10          1322          1261            4
# 2   True     61  white           5+10          1496          1500            3
# 3   True     61  white           20+0          1439          1454            3
# 4   True     95  white           30+3          1523          1469            5

# %%
df1 = df1.drop(['increment_code'] , axis = 1)

# %%
df1.head()
# Out:
#    rated  turns winner  white_rating  black_rating  opening_ply
# 0  False     13  white          1500          1191            5
# 1   True     16  black          1322          1261            4
# 2   True     61  white          1496          1500            3
# 3   True     61  white          1439          1454            3
# 4   True     95  white          1523          1469            5

# %%
df1["rated"] = df1["rated"]. replace("False", 0)

# %%
df1.head()
# Out:
#    rated  turns winner  white_rating  black_rating  opening_ply
# 0  False     13  white          1500          1191            5
# 1   True     16  black          1322          1261            4
# 2   True     61  white          1496          1500            3
# 3   True     61  white          1439          1454            3
# 4   True     95  white          1523          1469            5

# %%
df1["rated"] = df1["rated"]. replace("True", 1)

# %%
df1.head()
# Out:
#    rated  turns winner  white_rating  black_rating  opening_ply
# 0    NaN     13  white          1500          1191            5
# 1    NaN     16  black          1322          1261            4
# 2    NaN     61  white          1496          1500            3
# 3    NaN     61  white          1439          1454            3
# 4    NaN     95  white          1523          1469            5

# %%
df1.head()
# Out:
#    rated  turns winner  white_rating  black_rating  opening_ply
# 0    NaN     13  white          1500          1191            5
# 1    NaN     16  black          1322          1261            4
# 2    NaN     61  white          1496          1500            3
# 3    NaN     61  white          1439          1454            3
# 4    NaN     95  white          1523          1469            5

# %%
df1['rated'] = df['rated']

# %%
df1.head()
# Out:
#    rated  turns winner  white_rating  black_rating  opening_ply
# 0  False     13  white          1500          1191            5
# 1   True     16  black          1322          1261            4
# 2   True     61  white          1496          1500            3
# 3   True     61  white          1439          1454            3
# 4   True     95  white          1523          1469            5

# %%
df1 = df1['rated'].astype(int)

# %%
df1.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: rated, dtype: int32

# %% [markdown]
# df1.head()

# %%
df1.head()
# Out:
#    rated  turns winner  white_rating  black_rating  opening_ply
# 0  False     13  white          1500          1191            5
# 1   True     16  black          1322          1261            4
# 2   True     61  white          1496          1500            3
# 3   True     61  white          1439          1454            3
# 4   True     95  white          1523          1469            5

# %%
df1['rated'] = df1['rated'].astype(int)

# %%
df1.head()
# Out:
#    rated  turns winner  white_rating  black_rating  opening_ply
# 0      0     13  white          1500          1191            5
# 1      1     16  black          1322          1261            4
# 2      1     61  white          1496          1500            3
# 3      1     61  white          1439          1454            3
# 4      1     95  white          1523          1469            5

# %%
df1.head(10)
# Out:
#    rated  turns winner  white_rating  black_rating  opening_ply
# 0      0     13  white          1500          1191            5
# 1      1     16  black          1322          1261            4
# 2      1     61  white          1496          1500            3
# 3      1     61  white          1439          1454            3
# 4      1     95  white          1523          1469            5
# 5      0      5   draw          1250          1002            4
# 6      1     33  white          1520          1423           10
# 7      0      9  black          1413          2108            5
# 8      1     66  black          1439          1392            6
# 9      1    119  white          1381          1209            4

# %%
df1.replace('white' : 1)
# Out:
#   File "<ipython-input-44-71866a40ab41>", line 1
#     df1.replace('white' : 1)
#                         ^
# SyntaxError: invalid syntax

# %%
df1['winner'] = df["winner"].replace("white", 1).replace("black", 0).replace("draw", 1)

# %%
df1.head()
# Out:
#    rated  turns  winner  white_rating  black_rating  opening_ply
# 0      0     13       1          1500          1191            5
# 1      1     16       0          1322          1261            4
# 2      1     61       1          1496          1500            3
# 3      1     61       1          1439          1454            3
# 4      1     95       1          1523          1469            5

# %% [markdown]
# #

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df1.drop(['winner'] , axis = 1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_features = scaler.transform(df1.drop(['winner'] , axis = 1))

# %%
scaled_df = pd.DataFrame(scaled_features , columns= df1.columns[col])
# Out:
#   File "<ipython-input-60-ea0ba40dd240>", line 1
#     scaled_df = pd.DataFrame(scaled_features , columns= df1.columns.[col])
#                                                                     ^
# SyntaxError: invalid syntax

# %%
df1.columns[:2]
# Out:
# Index(['rated', 'turns'], dtype='object')

# %%
df1.columns[2:3]
# Out:
# Index(['winner'], dtype='object')

# %%
df1.columns
# Out:
# Index(['rated', 'turns', 'winner', 'white_rating', 'black_rating',
#        'opening_ply'],
#       dtype='object')

# %%
col = ['rated' , 'turns' , 'white_rating', 'black_rating',
       'opening_ply']

# %%
scaled_df = pd.DataFrame(scaled_features , columns= col)

# %%
scaled_df.head()
# Out:
#       rated     turns  white_rating  black_rating  opening_ply
# 0 -2.034484 -1.413952     -0.331788     -1.366985     0.065432
# 1  0.491525 -1.324585     -0.942955     -1.126459    -0.292083
# 2  0.491525  0.015907     -0.345522     -0.305234    -0.649599
# 3  0.491525  0.015907     -0.541233     -0.463294    -0.649599
# 4  0.491525  1.028724     -0.252817     -0.411753     0.065432

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_df , df1['winner'], test_size=0.33, random_state=42)

# %%
log_model = LogisticRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-92513504dcde> in <module>
# ----> 1 log_model = LogisticRegression()
#
# NameError: name 'LogisticRegression' is not defined

# %%
from sklearn.linear_model import LogisticRegression

# %%
lm = LogisticRegression()

# %%
lm.fit(X_train , y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred = lm.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test , pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.50      0.57      3007
#            1       0.65      0.77      0.71      3613
#
#     accuracy                           0.65      6620
#    macro avg       0.65      0.64      0.64      6620
# weighted avg       0.65      0.65      0.64      6620
